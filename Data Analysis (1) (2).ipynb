# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import xlrd

# %%
#data = pd.read_excel('workingDB_win101116.xls')
#data = pd.read_csv('modified.csv')
data = pd.read_excel('workingDB_win101116.xls')

# %%
data2.columns
# Out:
# Index(['diagnosis'], dtype='object')

# %%
data['diagnosis'] = data['Заключительный диагноз терапевта после ЛК']

# %%
data2 = pd.DataFrame(data['diagnosis'])

# %%
data.rename(index = {'.': 'Diagnosis'}, inplace=True)

# %%
data2.dtype
# Out:
# dtype('O')

# %%
data2.head()
# Out:
#                                            diagnosis
# 0                                                  .
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Гипохромная анемия, средней степени тяжести. Х...

# %%
data2 = data.drop([1,2], axis=0)

# %%
data2.head()
# Out:
#    Рег № общ  Рег. № наш        Ф.И.О. Unnamed: 3 Unnamed: 4  пол  \
# 0        NaN         NaN           NaN        NaN        NaN  NaN
# 3        NaN         NaN           NaN        NaN        NaN  NaN
# 4        1.0         1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN  1.0
# 5        2.0         2.0  ТУЛЕМУРАТОВА       ЛИЗА        NaN  0.0
# 6        3.0         3.0    БЕРДАЛИЕВА    АЛТЫНАЙ        NaN  0.0
#
#        дата\n рождения  возраст на момент обследования  \
# 0                  NaN                             NaN
# 3                  NaN                             NaN
# 4  1957-01-04 00:00:00                            57.0
# 5  1963-08-18 00:00:00                            50.0
# 6  1958-02-07 00:00:00                            56.0
#
#                                                                      Тяжелые металлы  \
# 0                                     ртуть (мкг/дл)
# 3                                           0,05-5,0
# ...

# %%
data.drop(['Рег. № наш'], axis=1, inplace=True)

# %%
list(data.columns)
# Out:
# ['Ф.И.О.',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'пол',
#  'дата\n рождения',
#  'возраст на момент обследования',
#  '                                                                   Тяжелые металлы',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'гемоглобин',
#  'эритроциты',
#  'лейкоциты',
#  'тромбоциты',
#  'СОЭ',
#  'Алат',
#  'Асат',
#  'Амилаза',
#  'Белок',
#  'Глюкоза',
#  'ГГТ',
#  'Креатинин',
#  'Мочевина',
#  'Щел.ф',
#  'Холест.',
#  'Триглиц.',
#  'Моч. кис.',
#  'Альбумин',
#  'Альфа 1',
#  'Альфа 2',
#  'Бета 1 ',
#  'Бета 2  ',
#  'гамма',
#  'HDL(липопротеины высокой плотности',
#  'VLDL(липопротеины промежуточной плотности)',
#  'LDL(липопротеины низкой плотности)',
#  'Unnamed: 46',
#  'Заключительный диагноз терапевта после ЛК']

# %%
data2.ix[:,:10].head()
# Out:
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#       Ф.И.О. Unnamed: 3 Unnamed: 4  пол      дата\n рождения  \
# 0        NaN        NaN        NaN  NaN                  NaN
# 1        NaN        NaN        NaN  NaN                  NaN
# 2        NaN        NaN        NaN  NaN                  NaN
# 3        NaN        NaN        NaN  NaN                  NaN
# 4  ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN  1.0  1957-01-04 00:00:00
#
#    возраст на момент обследования  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...

# %%
list(data2.columns[10:20])
# Out:
# ['Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'гемоглобин',
#  'эритроциты']

# %%
data3 = data.rename(columns={data2.columns[0]: 'lastname',
                                                                                data2.columns[1]: 'firstname', data2.columns[2]: 'middlename', 
                                                                                data2.columns[3]: 'gender', data2.columns[4]: 'birthdate', 
                                                                                data2.columns[5]: 'examage', data2.columns[6]: 'heavymetals:rtut', 
                                                                                data2.columns[7]:'heavymetals:svinec',
                                                                                data2.columns[8]:'heavymetals:med', data2.columns[9]:'heavymetals:cink',                                            
                                                                                data2.columns[10]:'heavymetals:kadmii', data2.columns[11]:'heavymetals:myshyak',
                                                                               data2.columns[12]:'heavymetals:chrome',data2.columns[13]:'heavymetals:selen',
                                                                               data2.columns[14]:'heavymetals:marganec',data2.columns[15]:'heavymetals:zhelezo',
                                                                               data2.columns[16]:'heavymetals:nikel',data2.columns[17]:'heavymetals:iod',
                                                                               data2.columns[18]:'gemoglobin:g/l', data2.columns[19]:'erotrocity:x1012/l',
                                                                               data2.columns[20]:'leikocity:x109/l',data2.columns[21]:'tromboocity:x109/l',
                                                                               data2.columns[22]:'coe:mm/ch',data2.columns[23]:'alat:ed/l',
                                                                               data2.columns[24]:'asat:ed/l',data2.columns[25]:'amilaza:ed/l',
                                                                               data2.columns[26]:'belok:g/l',data2.columns[27]:'glukoza:mmol/l',
                                                                               data2.columns[28]:'ggt:ed/l',data2.columns[29]:'kreatin:mkmol/l',
                                                                               data2.columns[30]:'mochevina:mmol/l',data2.columns[31]:'shelf:ed/l',
                                                                               data2.columns[32]:'holest:mmol/l',data2.columns[33]:'triglic:mkmol/l',
                                                                               data2.columns[34]:'mochkislota:mkmol/l',data2.columns[35]:'albumin:%:60,3-72,8',
                                                                               data2.columns[36]:'alpha1:%:1,0-2,6',data2.columns[37]:'alpha2:%:7,2-11,8',
                                                                               data2.columns[38]:'beta1:%:5,6-9,1',data2.columns[39]:'beta2:%:2,2-5,7',
                                                                               data2.columns[40]:'gamma:%:1,8-9,18',data2.columns[41]:'hdl:%:38,6-69,4',
                                                                               data2.columns[42]:'vldl:%:4,4-23,1',data2.columns[43]:'ldl:%:22,3-53,3',
                                                                               data2.columns[44]:'ficient:upto3.5', data2.columns[45]:'diagnosis'}, inplace = False)

# %%
list(data3.columns)
# Out:
# ['lastname',
#  'firstname',
#  'middlename',
#  'gender',
#  'birthdate',
#  'examage',
#  'heavymetals:rtut',
#  'heavymetals:svinec',
#  'heavymetals:med',
#  'heavymetals:cink',
#  'heavymetals:kadmii',
#  'heavymetals:myshyak',
#  'heavymetals:chrome',
#  'heavymetals:selen',
#  'heavymetals:marganec',
#  'heavymetals:zhelezo',
#  'heavymetals:nikel',
#  'heavymetals:iod',
#  'gemoglobin:g/l',
#  'erotrocity:x1012/l',
#  'leikocity:x109/l',
#  'tromboocity:x109/l',
#  'coe:mm/ch',
#  'alat:ed/l',
#  'asat:ed/l',
#  'amilaza:ed/l',
#  'belok:g/l',
#  'glukoza:mmol/l',
#  'ggt:ed/l',
#  'kreatin:mkmol/l',
#  'mochevina:mmol/l',
#  'shelf:ed/l',
#  'holest:mmol/l',
#  'triglic:mkmol/l',
#  'mochkislota:mkmol/l',
#  'albumin:%:60,3-72,8',
#  'alpha1:%:1,0-2,6',
#  'alpha2:%:7,2-11,8',
#  'beta1:%:5,6-9,1',
#  'beta2:%:2,2-5,7',
#  'gamma:%:1,8-9,18',
#  'hdl:%:38,6-69,4',
#  'vldl:%:4,4-23,1',
#  'ldl:%:22,3-53,3',
#  'ficient:upto3.5',
#  'diagnosis']

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 46 columns):
# lastname                772 non-null object
# firstname               772 non-null object
# middlename              466 non-null object
# gender                  772 non-null float64
# birthdate               772 non-null object
# examage                 772 non-null float64
# heavymetals:rtut        792 non-null object
# heavymetals:svinec      802 non-null object
# heavymetals:med         801 non-null object
# heavymetals:cink        802 non-null object
# heavymetals:kadmii      802 non-null object
# heavymetals:myshyak     802 non-null object
# heavymetals:chrome      802 non-null object
# heavymetals:selen       802 non-null object
# heavymetals:marganec    802 non-null object
# heavymetals:zhelezo     802 non-null object
# heavymetals:nikel       802 non-null object
# heavymetals:iod         801 non-null object
# gemoglobin:g/l          799 non-null object
# ...

# %%
data3.head()
# Out:
#        lastname  firstname  middlename  gender            birthdate  examage  \
# 4     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN     1.0  1957-01-04 00:00:00     57.0
# 5  ТУЛЕМУРАТОВА       ЛИЗА         NaN     0.0  1963-08-18 00:00:00     50.0
# 6    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN     0.0  1958-02-07 00:00:00     56.0
# 7       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ     1.0  1963-03-19 00:00:00     51.0
# 8       БОКАЕВА     САБИЛА         NaN     0.0  1963-06-06 00:00:00     51.0
#
#   heavymetals:rtut heavymetals:svinec heavymetals:med heavymetals:cink  ...  \
# 4              0.8                3.2            1741           3733.2  ...
# 5              0.9                 10             890           1761.7  ...
# 6              0.8                5.4          1584.2           2865.4  ...
# 7              0.6                  3          1331.5             4104  ...
# 8              0.6                3.9            1850           1937.6  ...
#
# ...

# %%
data3.drop(data3.index[776:], axis=0, inplace=True)

# %%
data3.head()
# Out:
#     lastname  firstname middlename  gender            birthdate  examage  \
# 0        NaN        NaN        NaN     NaN                  NaN      NaN
# 1        NaN        NaN        NaN     NaN                  NaN      NaN
# 2        NaN        NaN        NaN     NaN                  NaN      NaN
# 3        NaN        NaN        NaN     NaN                  NaN      NaN
# 4  ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN     1.0  1957-01-04 00:00:00     57.0
#
#   heavymetals:rtut heavymetals:svinec heavymetals:med heavymetals:cink  ...  \
# 0   ртуть (мкг/дл)    свинец (мкг/дл)     медь(мкг/л)     цинк (мкг/л)  ...
# 1              NaN                NaN             NaN              NaN  ...
# 2              NaN                NaN             NaN              NaN  ...
# 3         0,05-5,0              до 25        800-1300        4000-8600  ...
# 4              0.8                3.2            1741           3733.2  ...
#
# ...

# %%
data3.head()
# Out:
#       firstname middlename      gender  birthdate              examage  \
# 4     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN        1.0  1957-01-04 00:00:00
# 5  ТУЛЕМУРАТОВА       ЛИЗА         NaN        0.0  1963-08-18 00:00:00
# 6    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN        0.0  1958-02-07 00:00:00
# 7       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ        1.0  1963-03-19 00:00:00
# 8       БОКАЕВА     САБИЛА         NaN        0.0  1963-06-06 00:00:00
#
#    heavymetals:rtut heavymetals:svinec heavymetals:svinec heavymetals:med  \
# 4              57.0                0.8                3.2            1741
# 5              50.0                0.9                 10             890
# 6              56.0                0.8                5.4          1584.2
# 7              51.0                0.6                  3          1331.5
# 8              51.0                0.6                3.9            1850
#
#   heavymetals:cink  ... alpha1:%:1,0-2,6 alpha2:%:7,2-11,8 beta1:%:5,6-9,1  \
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 0 to 775
# Data columns (total 46 columns):
# lastname                772 non-null object
# firstname               772 non-null object
# middlename              466 non-null object
# gender                  772 non-null float64
# birthdate               772 non-null object
# examage                 772 non-null float64
# heavymetals:rtut        766 non-null object
# heavymetals:svinec      774 non-null object
# heavymetals:med         773 non-null object
# heavymetals:cink        774 non-null object
# heavymetals:kadmii      774 non-null object
# heavymetals:myshyak     774 non-null object
# heavymetals:chrome      774 non-null object
# heavymetals:selen       774 non-null object
# heavymetals:marganec    774 non-null object
# heavymetals:zhelezo     774 non-null object
# heavymetals:nikel       774 non-null object
# heavymetals:iod         773 non-null object
# gemoglobin:g/l          772 non-null object
# ...

# %%
cols = data3.columns[6:45]

# %%
cols
# Out:
# Index(['heavymetals:rtut', 'heavymetals:svinec', 'heavymetals:med',
#        'heavymetals:cink', 'heavymetals:kadmii', 'heavymetals:myshyak',
#        'heavymetals:chrome', 'heavymetals:selen', 'heavymetals:marganec',
#        'heavymetals:zhelezo', 'heavymetals:nikel', 'heavymetals:iod',
#        'gemoglobin:g/l', 'erotrocity:x1012/l', 'leikocity:x109/l',
#        'tromboocity:x109/l', 'coe:mm/ch', 'alat:ed/l', 'asat:ed/l',
#        'amilaza:ed/l', 'belok:g/l', 'glukoza:mmol/l', 'ggt:ed/l',
#        'kreatin:mkmol/l', 'mochevina:mmol/l', 'shelf:ed/l', 'holest:mmol/l',
#        'triglic:mkmol/l', 'mochkislota:mkmol/l', 'albumin:%:60,3-72,8',
#        'alpha1:%:1,0-2,6', 'alpha2:%:7,2-11,8', 'beta1:%:5,6-9,1',
#        'beta2:%:2,2-5,7', 'gamma:%:1,8-9,18', 'hdl:%:38,6-69,4',
#        'vldl:%:4,4-23,1', 'ldl:%:22,3-53,3', 'ficient:upto3.5'],
#       dtype='object')

# %%
data4 = data3[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
data4.head()
# Out:
#    heavymetals:rtut  heavymetals:svinec  heavymetals:med  heavymetals:cink  \
# 0               NaN                 NaN              NaN               NaN
# 1               NaN                 NaN              NaN               NaN
# 2               NaN                 NaN              NaN               NaN
# 3               NaN                 NaN              NaN               NaN
# 4               0.8                 3.2           1741.0            3733.2
#
#    heavymetals:kadmii  heavymetals:myshyak  heavymetals:chrome  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3                 NaN                  NaN                 NaN
# 4                 1.0                  0.1                 0.5
#
#    heavymetals:selen  heavymetals:marganec  heavymetals:zhelezo  ...  \
# ...

# %%
data4.tail()
# Out:
#      heavymetals:rtut  heavymetals:svinec  heavymetals:med  heavymetals:cink  \
# 771               0.5                 4.3           1263.4            4751.2
# 772               0.6                 3.8           1178.4            3759.6
# 773               0.3                 5.0           1265.0            3762.5
# 774               0.4                 7.3            912.6            4612.3
# 775               4.0                 5.1           3892.5            3425.1
#
#      heavymetals:kadmii  heavymetals:myshyak  heavymetals:chrome  \
# 771                 0.6                0.020                 1.4
# 772                 0.9                0.013                 1.2
# 773                 0.6                0.080                 2.1
# 774                 0.5                0.030                 1.3
# 775                 3.0                0.040                 6.0
#
#      heavymetals:selen  heavymetals:marganec  heavymetals:zhelezo  ...  \
# ...

# %%
data5 = pd.DataFrame(data3.iloc[:,:6], columns=data3.columns[:6])

# %%
data3.iloc[:,:6].head()
# Out:
#     lastname  firstname middlename  gender            birthdate  examage
# 0        NaN        NaN        NaN     NaN                  NaN      NaN
# 1        NaN        NaN        NaN     NaN                  NaN      NaN
# 2        NaN        NaN        NaN     NaN                  NaN      NaN
# 3        NaN        NaN        NaN     NaN                  NaN      NaN
# 4  ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN     1.0  1957-01-04 00:00:00     57.0

# %%
data5.tail()
# Out:
#        lastname firstname    middlename  gender            birthdate  examage
# 771  ФАЙЗУЛЛАЕВ    УТЕБАЙ  ТУЖМУРАТОВИЧ     1.0  1959-05-29 00:00:00     55.0
# 772     САГАТОВ    КУАНЫШ           NaN     1.0           08.04.1955     59.0
# 773    САРБАСОВ  БАКЫТБЕК           NaN     1.0  1966-10-09 00:00:00     47.0
# 774    КИЛИБАЕВ   ЕРБАХЫТ    УТЕГЕНОВИЧ     1.0  1963-08-30 00:00:00     51.0
# 775    ОРАЗАШЕВ     ДУЛАТ           NaN     1.0           15.06.1988     26.0

# %%
data6 = pd.concat([data5, data4], axis=1)

# %%
data6['diagnosis'] = data3['diagnosis']

# %%
data7.tail()
# Out:
#        lastname firstname    middlename  gender            birthdate  examage  \
# 767  ФАЙЗУЛЛАЕВ    УТЕБАЙ  ТУЖМУРАТОВИЧ     1.0  1959-05-29 00:00:00     55.0
# 768     САГАТОВ    КУАНЫШ           NaN     1.0           08.04.1955     59.0
# 769    САРБАСОВ  БАКЫТБЕК           NaN     1.0  1966-10-09 00:00:00     47.0
# 770    КИЛИБАЕВ   ЕРБАХЫТ    УТЕГЕНОВИЧ     1.0  1963-08-30 00:00:00     51.0
# 771    ОРАЗАШЕВ     ДУЛАТ           NaN     1.0           15.06.1988     26.0
#
#      heavymetals:rtut  heavymetals:svinec  heavymetals:med  heavymetals:cink  \
# 767               0.5                 4.3           1263.4            4751.2
# 768               0.6                 3.8           1178.4            3759.6
# 769               0.3                 5.0           1265.0            3762.5
# 770               0.4                 7.3            912.6            4612.3
# 771               4.0                 5.1           3892.5            3425.1
#
# ...

# %%
data6.drop(data6.index[:4], axis=0, inplace=True)

# %%
data7=data6.reset_index(drop=True)

# %%
data7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 46 columns):
# lastname                772 non-null object
# firstname               772 non-null object
# middlename              466 non-null object
# gender                  772 non-null float64
# birthdate               772 non-null object
# examage                 772 non-null float64
# heavymetals:rtut        764 non-null float64
# heavymetals:svinec      772 non-null float64
# heavymetals:med         771 non-null float64
# heavymetals:cink        772 non-null float64
# heavymetals:kadmii      772 non-null float64
# heavymetals:myshyak     772 non-null float64
# heavymetals:chrome      772 non-null float64
# heavymetals:selen       772 non-null float64
# heavymetals:marganec    771 non-null float64
# heavymetals:zhelezo     772 non-null float64
# heavymetals:nikel       772 non-null float64
# heavymetals:iod         771 non-null float64
# gemoglobin:g/l          770 non-null float64
# ...

# %%
data5.corr()
# Out:
#                            num    gender   examage  heavymetals:rtut  \
# num                   1.000000  0.506334  0.001655          0.025424
# gender                0.506334  1.000000  0.102103         -0.079669
# examage               0.001655  0.102103  1.000000         -0.462390
# heavymetals:rtut      0.025424 -0.079669 -0.462390          1.000000
# heavymetals:svinec    0.015697 -0.008359  0.065820         -0.018335
# heavymetals:svinec   -0.143106  0.090527 -0.265626          0.160066
# heavymetals:svinec    0.015697 -0.008359  0.065820         -0.018335
# heavymetals:svinec   -0.143106  0.090527 -0.265626          0.160066
# heavymetals:med       0.207388 -0.131023  0.270999         -0.093049
# heavymetals:cink     -0.029288  0.047930  0.004350          0.054713
# heavymetals:kadmii   -0.060925 -0.149930 -0.252318          0.266372
# heavymetals:myshyak   0.198208 -0.022931 -0.049189          0.059914
# heavymetals:chrome    0.157187 -0.199832  0.255799         -0.106930
# ...

# %%
data5.describe()
# Out:
#                num      gender     examage  heavymetals:rtut  \
# count   778.000000  778.000000  778.000000        770.000000
# mean    622.843188    0.467866   45.938303          0.815714
# std     344.325657    0.499287   13.871493          0.794499
# min       1.000000    0.000000   16.000000          0.100000
# 25%     326.500000    0.000000   35.000000          0.400000
# 50%     670.500000    0.000000   47.000000          0.600000
# 75%     922.750000    1.000000   57.000000          0.800000
# max    1181.000000    1.000000   77.000000          5.000000
#
#        heavymetals:svinec  heavymetals:svinec  heavymetals:svinec  \
# count          778.000000          777.000000          778.000000
# mean             4.665938         1312.507593            4.665938
# std              1.912362          275.132133            1.912362
# min              0.300000          670.000000            0.300000
# 25%              3.425000         1165.300000            3.425000
# ...

# %%
data7.to_csv('modified6.csv', encoding='utf-8-sig')

# %%
from datetime import datetime

# %%
data7['birthdate'] = data7['birthdate'].astype('str')

# %%
datetime.strptime(data7['birthdate'], '%y/%m/%d')
#data5['birthdate'].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-46734d6f97a5> in <module>
# ----> 1 datetime.strptime(data7['birthdate'], '%y/%m/%d')
#       2 #data5['birthdate'].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
data7['birthdate'].dtype
# Out:
# dtype('float64')

# %%
data7.tail()
# Out:
#       firstname middlename        gender  birthdate              examage  \
# 767  ФАЙЗУЛЛАЕВ     УТЕБАЙ  ТУЖМУРАТОВИЧ        1.0  1959-05-29 00:00:00
# 768     САГАТОВ     КУАНЫШ           NaN        1.0           08.04.1955
# 769    САРБАСОВ   БАКЫТБЕК           NaN        1.0  1966-10-09 00:00:00
# 770    КИЛИБАЕВ    ЕРБАХЫТ    УТЕГЕНОВИЧ        1.0  1963-08-30 00:00:00
# 771    ОРАЗАШЕВ      ДУЛАТ           NaN        1.0           15.06.1988
#
#      heavymetals:rtut  heavymetals:svinec  heavymetals:svinec  \
# 767              55.0                 0.5                 4.3
# 768              59.0                 0.6                 3.8
# 769              47.0                 0.3                 5.0
# 770              51.0                 0.4                 7.3
# 771              26.0                 4.0                 5.1
#
#      heavymetals:svinec  heavymetals:svinec  ...  alpha1:%:1,0-2,6  \
# 767                 0.5                 4.3  ...               1.6
# ...

# %%
data7['birthdate'] = pd.to_datetime(data7['birthdate'])

# %%
data7['birthdate'].dtype
# Out:
# dtype('O')

# %%
data.to_csv('modified4.csv', encoding='utf-8-sig')

# %%
data4 = pd.read_csv('modified3.csv')

# %%
data7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 46 columns):
# lastname                772 non-null object
# firstname               772 non-null object
# middlename              466 non-null object
# gender                  772 non-null float64
# birthdate               772 non-null datetime64[ns]
# examage                 772 non-null float64
# heavymetals:rtut        764 non-null float64
# heavymetals:svinec      772 non-null float64
# heavymetals:med         771 non-null float64
# heavymetals:cink        772 non-null float64
# heavymetals:kadmii      772 non-null float64
# heavymetals:myshyak     772 non-null float64
# heavymetals:chrome      772 non-null float64
# heavymetals:selen       772 non-null float64
# heavymetals:marganec    771 non-null float64
# heavymetals:zhelezo     772 non-null float64
# heavymetals:nikel       772 non-null float64
# heavymetals:iod         771 non-null float64
# ...

# %%
sns.pairplot(data7.iloc[:360,6:17])
# Out:
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(data7.iloc[:360,17:28])

# %%
sns.pairplot(data7.iloc[:360,28:39])

# %%
sns.pairplot(data7.iloc[:360,39:])

# %%
sns.distplot(data7['gemoglobin:g/l'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-276-5880662cca62> in <module>
# ----> 1 sns.distplot(data7['gemoglobin:g/l'])
#
# ~\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ...

# %%
data3 = data2.fillna(method='ffill')
