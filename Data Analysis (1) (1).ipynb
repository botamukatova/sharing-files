# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data = pd.read_excel('workingDB_win101116.xls')

data = pd.read_csv('modified.csv')

# %%
data.head(10)
# Out:
#    Рег № общ  Рег. № наш        Ф.И.О. Unnamed: 3  Unnamed: 4  пол  \
# 0        NaN         NaN           NaN        NaN         NaN  NaN
# 1        NaN         NaN           NaN        NaN         NaN  NaN
# 2        NaN         NaN           NaN        NaN         NaN  NaN
# 3        NaN         NaN           NaN        NaN         NaN  NaN
# 4        1.0         1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN  1.0
# 5        2.0         2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN  0.0
# 6        3.0         3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN  0.0
# 7        4.0         4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ  1.0
# 8        5.0         5.0       БОКАЕВА     САБИЛА         NaN  0.0
# 9        6.0         6.0      ИБРАШЕВА       РОЗА  МАКСАТОВНА  0.0
#
#        дата\n рождения  возраст на момент обследования  \
# 0                  NaN                             NaN
# 1                  NaN                             NaN
# 2                  NaN                             NaN
# ...

# %%
data2 = data.drop([1,2], axis=0)

# %%
data2.head()
# Out:
#    Рег № общ  Рег. № наш        Ф.И.О. Unnamed: 3 Unnamed: 4  пол  \
# 0        NaN         NaN           NaN        NaN        NaN  NaN
# 3        NaN         NaN           NaN        NaN        NaN  NaN
# 4        1.0         1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN  1.0
# 5        2.0         2.0  ТУЛЕМУРАТОВА       ЛИЗА        NaN  0.0
# 6        3.0         3.0    БЕРДАЛИЕВА    АЛТЫНАЙ        NaN  0.0
#
#        дата\n рождения  возраст на момент обследования  \
# 0                  NaN                             NaN
# 3                  NaN                             NaN
# 4  1957-01-04 00:00:00                            57.0
# 5  1963-08-18 00:00:00                            50.0
# 6  1958-02-07 00:00:00                            56.0
#
#                                                                      Тяжелые металлы  \
# 0                                     ртуть (мкг/дл)
# 3                                           0,05-5,0
# ...

# %%
data2.drop(['Рег № общ'], axis=1, inplace=True)

# %%
data2.head(10)
# Out:
#     Рег. № наш        Ф.И.О. Unnamed: 3  Unnamed: 4  пол      дата\n рождения  \
# 0          NaN           NaN        NaN         NaN  NaN                  NaN
# 3          NaN           NaN        NaN         NaN  NaN                  NaN
# 4          1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN  1.0  1957-01-04 00:00:00
# 5          2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN  0.0  1963-08-18 00:00:00
# 6          3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN  0.0  1958-02-07 00:00:00
# 7          4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ  1.0  1963-03-19 00:00:00
# 8          5.0       БОКАЕВА     САБИЛА         NaN  0.0  1963-06-06 00:00:00
# 9          6.0      ИБРАШЕВА       РОЗА  МАКСАТОВНА  0.0  1965-12-13 00:00:00
# 10         7.0   ДЖУГАНИСОВА      ЛАУРА    АБИЛОВНА  0.0  1965-08-01 00:00:00
# 11         8.0  КАРАМУРЗАЕВА      САРА          NaN  0.0  1968-10-17 00:00:00
#
#     возраст на момент обследования  \
# 0                              NaN
# 3                              NaN
# ...

# %%
data3 = data2.rename(columns={data2.columns[0]: 'num', data2.columns[1]: 'lastname',
                                                                                data2.columns[2]: 'firstname', data2.columns[3]: 'middlename', 
                                                                                data2.columns[4]: 'gender', data2.columns[5]: 'birthdate', 
                                                                                data2.columns[6]: 'examage', data2.columns[7]: 'heavymetals:rtut', 
                                                                                data2.columns[8]: 'heavymetals:svinec', data2.columns[9]:'heavymetals:svinec',
                                                                                data2.columns[10]:'heavymetals:med', data2.columns[11]:'heavymetals:cink',                                            
                                                                                data2.columns[12]:'heavymetals:kadmii', data2.columns[13]:'heavymetals:myshyak',
                                                                               data2.columns[14]:'heavymetals:chrome',data2.columns[15]:'heavymetals:selen',
                                                                               data2.columns[16]:'heavymetals:marganec',data2.columns[17]:'heavymetals:zhelezo',
                                                                               data2.columns[18]:'heavymetals:nikel',data2.columns[19]:'heavymetals:iod',
                                                                               data2.columns[20]:'gemoglobin:g/l', data2.columns[21]:'erotrocity:x1012/l',
                                                                               data2.columns[22]:'leikocity:x109/l',data2.columns[23]:'tromboocity:x109/l',
                                                                               data2.columns[24]:'coe:mm/ch',data2.columns[25]:'alat:ed/l',
                                                                               data2.columns[26]:'asat:ed/l',data2.columns[27]:'amilaza:ed/l',
                                                                               data2.columns[28]:'belok:g/l',data2.columns[29]:'glukoza:mmol/l',
                                                                               data2.columns[30]:'ggt:ed/l',data2.columns[31]:'kreatin:mkmol/l',
                                                                               data2.columns[32]:'mochevina:mmol/l',data2.columns[33]:'shelf:ed/l',
                                                                               data2.columns[34]:'holest:mmol/l',data2.columns[35]:'triglic:mkmol/l',
                                                                               data2.columns[36]:'mochkislota:mkmol/l',data2.columns[37]:'albumin:%:60,3-72,8',
                                                                               data2.columns[38]:'alpha1:%:1,0-2,6',data2.columns[39]:'alpha2:%:7,2-11,8',
                                                                               data2.columns[40]:'beta1:%:5,6-9,1',data2.columns[41]:'beta2:%:2,2-5,7',
                                                                               data2.columns[42]:'gamma:%:1,8-9,18',data2.columns[43]:'hdl:%:38,6-69,4',
                                                                               data2.columns[44]:'vldl:%:4,4-23,1',data2.columns[45]:'ldl:%:22,3-53,3',
                                                                               data2.columns[46]:'ficient:upto3.5'}, inplace = False)

# %%
list(data2.columns)
# Out:
# ['Рег. № наш',
#  'Ф.И.О.',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'пол',
#  'дата\n рождения',
#  'возраст на момент обследования',
#  '                                                                   Тяжелые металлы',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'гемоглобин',
#  'эритроциты',
#  'лейкоциты',
#  'тромбоциты',
#  'СОЭ',
#  'Алат',
#  'Асат',
#  'Амилаза',
#  'Белок',
#  'Глюкоза',
#  'ГГТ',
#  'Креатинин',
#  'Мочевина',
#  'Щел.ф',
#  'Холест.',
#  'Триглиц.',
#  'Моч. кис.',
#  'Альбумин',
#  'Альфа 1',
#  'Альфа 2',
#  'Бета 1 ',
#  'Бета 2  ',
#  'гамма',
#  'HDL(липопротеины высокой плотности',
#  'VLDL(липопротеины промежуточной плотности)',
#  'LDL(липопротеины низкой плотности)',
#  'Unnamed: 46',
#  'Заключительный диагноз терапевта после ЛК']

# %%
list(data2.iloc[0])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ртуть (мкг/дл)',
#  'свинец (мкг/дл)',
#  'медь(мкг/л)',
#  'цинк (мкг/л)',
#  'кадмий (мкг/дл)',
#  'мышьяк (мкг/дл)',
#  'хром (мкг/л)',
#  'селен (мкг/л)',
#  'марганец (мкг/л)',
#  'железо  (мг/л)',
#  'никель  (мкг/л)',
#  'йод  (мкг/л)',
#  '(г/л)',
#  'х1012/л',
#  'х109/л',
#  'х109/л',
#  'мм/час',
#  '(ед/л)',
#  '(ед/л)',
#  '(ед/л)',
#  '(г/л)',
#  '(ммоль/л)',
#  '(ед/л)',
#  '(мкмоль/л)',
#  '(ммоль/л)',
#  '(ед/л)',
#  '(ммоль/л)',
#  '(мкмоль/л)',
#  '(мкмоль/л)',
#  '% ',
#  ' %',
#  ' %',
#  ' %',
#  '%',
#  '  %',
#  '%',
#  '%',
#  '%',
#  'КА(коэффициент атерогенности)',
#  '.']

# %%
data3.columns[1]
# Out:
# 'lastname'

# %%
data3.head()
# Out:
#    num      lastname  firstname middlename  gender            birthdate  \
# 0  NaN           NaN        NaN        NaN     NaN                  NaN
# 3  NaN           NaN        NaN        NaN     NaN                  NaN
# 4  1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР        NaN     1.0  1957-01-04 00:00:00
# 5  2.0  ТУЛЕМУРАТОВА       ЛИЗА        NaN     0.0  1963-08-18 00:00:00
# 6  3.0    БЕРДАЛИЕВА    АЛТЫНАЙ        NaN     0.0  1958-02-07 00:00:00
#
#    examage heavymetals:rtut heavymetals:svinec heavymetals:svinec  \
# 0      NaN   ртуть (мкг/дл)    свинец (мкг/дл)        медь(мкг/л)
# 3      NaN         0,05-5,0              до 25           800-1300
# 4     57.0              0.8                3.2               1741
# 5     50.0              0.9                 10                890
# 6     56.0              0.8                5.4             1584.2
#
#                          ...                         albumin:%:60,3-72,8  \
# ...

# %%
list(data3.columns)
# Out:
# ['num',
#  'lastname',
#  'firstname',
#  'middlename',
#  'gender',
#  'birthdate',
#  'examage',
#  'heavymetals:rtut',
#  'heavymetals:svinec',
#  'heavymetals:svinec',
#  'heavymetals:med',
#  'heavymetals:cink',
#  'heavymetals:kadmii',
#  'heavymetals:myshyak',
#  'heavymetals:chrome',
#  'heavymetals:selen',
#  'heavymetals:marganec',
#  'heavymetals:zhelezo',
#  'heavymetals:nikel',
#  'heavymetals:iod',
#  'gemoglobin:g/l',
#  'erotrocity:x1012/l',
#  'leikocity:x109/l',
#  'tromboocity:x109/l',
#  'coe:mm/ch',
#  'alat:ed/l',
#  'asat:ed/l',
#  'amilaza:ed/l',
#  'belok:g/l',
#  'glukoza:mmol/l',
#  'ggt:ed/l',
#  'kreatin:mkmol/l',
#  'mochevina:mmol/l',
#  'shelf:ed/l',
#  'holest:mmol/l',
#  'triglic:mkmol/l',
#  'mochkislota:mkmol/l',
#  'albumin:%:60,3-72,8',
#  'alpha1:%:1,0-2,6',
#  'alpha2:%:7,2-11,8',
#  'beta1:%:5,6-9,1',
#  'beta2:%:2,2-5,7',
#  'gamma:%:1,8-9,18',
#  'hdl:%:38,6-69,4',
#  'vldl:%:4,4-23,1',
#  'ldl:%:22,3-53,3',
#  'ficient:upto3.5']

# %%
data3.drop(data3.index[774:], axis=0, inplace=True)

# %%
data3.tail()
# Out:
#         num    lastname firstname    middlename  gender            birthdate  \
# 771  1175.0  ФАЙЗУЛЛАЕВ    УТЕБАЙ  ТУЖМУРАТОВИЧ     1.0  1959-05-29 00:00:00
# 772  1176.0     САГАТОВ    КУАНЫШ           NaN     1.0           08.04.1955
# 773  1178.0    САРБАСОВ  БАКЫТБЕК           NaN     1.0  1966-10-09 00:00:00
# 774  1179.0    КИЛИБАЕВ   ЕРБАХЫТ    УТЕГЕНОВИЧ     1.0  1963-08-30 00:00:00
# 775  1181.0    ОРАЗАШЕВ     ДУЛАТ           NaN     1.0           15.06.1988
#
#      examage heavymetals:rtut heavymetals:svinec heavymetals:svinec  \
# 771     55.0              0.5                4.3             1263.4
# 772     59.0              0.6                3.8             1178.4
# 773     47.0              0.3                  5               1265
# 774     51.0              0.4                7.3              912.6
# 775     26.0                4                5.1             3892.5
#
#                            ...                         albumin:%:60,3-72,8  \
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 774 entries, 0 to 775
# Data columns (total 47 columns):
# num                     772 non-null float64
# lastname                772 non-null object
# firstname               772 non-null object
# middlename              466 non-null object
# gender                  772 non-null float64
# birthdate               772 non-null object
# examage                 772 non-null float64
# heavymetals:rtut        766 non-null object
# heavymetals:svinec      774 non-null object
# heavymetals:svinec      773 non-null object
# heavymetals:med         774 non-null object
# heavymetals:cink        774 non-null object
# heavymetals:kadmii      774 non-null object
# heavymetals:myshyak     774 non-null object
# heavymetals:chrome      774 non-null object
# heavymetals:selen       774 non-null object
# heavymetals:marganec    774 non-null object
# heavymetals:zhelezo     774 non-null object
# heavymetals:nikel       773 non-null object
# ...

# %%
data3.drop(data3.index[0:2], axis=0, inplace=True)

# %%
data3.tail()
# Out:
#         num    lastname firstname    middlename  gender            birthdate  \
# 771  1175.0  ФАЙЗУЛЛАЕВ    УТЕБАЙ  ТУЖМУРАТОВИЧ     1.0  1959-05-29 00:00:00
# 772  1176.0     САГАТОВ    КУАНЫШ           NaN     1.0           08.04.1955
# 773  1178.0    САРБАСОВ  БАКЫТБЕК           NaN     1.0  1966-10-09 00:00:00
# 774  1179.0    КИЛИБАЕВ   ЕРБАХЫТ    УТЕГЕНОВИЧ     1.0  1963-08-30 00:00:00
# 775  1181.0    ОРАЗАШЕВ     ДУЛАТ           NaN     1.0           15.06.1988
#
#      examage heavymetals:rtut heavymetals:svinec heavymetals:svinec  \
# 771     55.0              0.5                4.3             1263.4
# 772     59.0              0.6                3.8             1178.4
# 773     47.0              0.3                  5               1265
# 774     51.0              0.4                7.3              912.6
# 775     26.0                4                5.1             3892.5
#
#                            ...                         albumin:%:60,3-72,8  \
# ...

# %%
data3.head()
# Out:
#    num      lastname  firstname  middlename  gender            birthdate  \
# 4  1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN     1.0  1957-01-04 00:00:00
# 5  2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN     0.0  1963-08-18 00:00:00
# 6  3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN     0.0  1958-02-07 00:00:00
# 7  4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ     1.0  1963-03-19 00:00:00
# 8  5.0       БОКАЕВА     САБИЛА         NaN     0.0  1963-06-06 00:00:00
#
#    examage heavymetals:rtut heavymetals:svinec heavymetals:svinec  \
# 4     57.0              0.8                3.2               1741
# 5     50.0              0.9                 10                890
# 6     56.0              0.8                5.4             1584.2
# 7     51.0              0.6                  3             1331.5
# 8     51.0              0.6                3.9               1850
#
#                          ...                         albumin:%:60,3-72,8  \
# ...

# %%
data3.dtypes
# Out:
# num                     float64
# lastname                 object
# firstname                object
# middlename               object
# gender                  float64
# birthdate                object
# examage                 float64
# heavymetals:rtut         object
# heavymetals:svinec       object
# heavymetals:svinec       object
# heavymetals:med          object
# heavymetals:cink         object
# heavymetals:kadmii       object
# heavymetals:myshyak      object
# heavymetals:chrome       object
# heavymetals:selen        object
# heavymetals:marganec     object
# heavymetals:zhelezo      object
# heavymetals:nikel        object
# heavymetals:iod          object
# gemoglobin:g/l           object
# erotrocity:x1012/l       object
# leikocity:x109/l         object
# tromboocity:x109/l       object
# coe:mm/ch                object
# alat:ed/l                object
# asat:ed/l                object
# amilaza:ed/l             object
# belok:g/l                object
# ...

# %%
cols = data3.columns[7:]

# %%
cols
# Out:
# Index(['heavymetals:rtut', 'heavymetals:svinec', 'heavymetals:svinec',
#        'heavymetals:med', 'heavymetals:cink', 'heavymetals:kadmii',
#        'heavymetals:myshyak', 'heavymetals:chrome', 'heavymetals:selen',
#        'heavymetals:marganec', 'heavymetals:zhelezo', 'heavymetals:nikel',
#        'heavymetals:iod', 'gemoglobin:g/l', 'erotrocity:x1012/l',
#        'leikocity:x109/l', 'tromboocity:x109/l', 'coe:mm/ch', 'alat:ed/l',
#        'asat:ed/l', 'amilaza:ed/l', 'belok:g/l', 'glukoza:mmol/l', 'ggt:ed/l',
#        'kreatin:mkmol/l', 'mochevina:mmol/l', 'shelf:ed/l', 'holest:mmol/l',
#        'triglic:mkmol/l', 'mochkislota:mkmol/l', 'albumin:%:60,3-72,8',
#        'alpha1:%:1,0-2,6', 'alpha2:%:7,2-11,8', 'beta1:%:5,6-9,1',
#        'beta2:%:2,2-5,7', 'gamma:%:1,8-9,18', 'hdl:%:38,6-69,4',
#        'vldl:%:4,4-23,1', 'ldl:%:22,3-53,3', 'ficient:upto3.5'],
#       dtype='object')

# %%
data4 = data3[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
data4.head()
# Out:
#    heavymetals:rtut  heavymetals:svinec  heavymetals:svinec  \
# 4               0.8                 3.2              1741.0
# 5               0.9                10.0               890.0
# 6               0.8                 5.4              1584.2
# 7               0.6                 3.0              1331.5
# 8               0.6                 3.9              1850.0
#
#    heavymetals:svinec  heavymetals:svinec  heavymetals:med  heavymetals:cink  \
# 4                 3.2              1741.0           3733.2               1.0
# 5                10.0               890.0           1761.7               0.5
# 6                 5.4              1584.2           2865.4               0.9
# 7                 3.0              1331.5           4104.0               0.7
# 8                 3.9              1850.0           1937.6               0.4
#
#    heavymetals:kadmii  heavymetals:myshyak  heavymetals:chrome  \
# 4               0.100                  0.5                47.3
# ...

# %%
data4['num'] = data3['num']

# %%
data3.drop(data3.columns[7:], axis=1, inplace=True)

# %%
data3.head()
# Out:
#    num      lastname  firstname  middlename  gender            birthdate  \
# 4  1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN     1.0  1957-01-04 00:00:00
# 5  2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN     0.0  1963-08-18 00:00:00
# 6  3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN     0.0  1958-02-07 00:00:00
# 7  4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ     1.0  1963-03-19 00:00:00
# 8  5.0       БОКАЕВА     САБИЛА         NaN     0.0  1963-06-06 00:00:00
#
#    examage
# 4     57.0
# 5     50.0
# 6     56.0
# 7     51.0
# 8     51.0

# %%
data5 = data3.join(data4.set_index('num'), on='num')

# %%
data5.dtypes
# Out:
# num                     float64
# lastname                 object
# firstname                object
# middlename               object
# gender                  float64
# birthdate                object
# examage                 float64
# heavymetals:rtut        float64
# heavymetals:svinec      float64
# heavymetals:svinec      float64
# heavymetals:svinec      float64
# heavymetals:svinec      float64
# heavymetals:med         float64
# heavymetals:cink        float64
# heavymetals:kadmii      float64
# heavymetals:myshyak     float64
# heavymetals:chrome      float64
# heavymetals:selen       float64
# heavymetals:marganec    float64
# heavymetals:zhelezo     float64
# heavymetals:nikel       float64
# heavymetals:iod         float64
# gemoglobin:g/l          float64
# erotrocity:x1012/l      float64
# leikocity:x109/l        float64
# tromboocity:x109/l      float64
# coe:mm/ch               float64
# alat:ed/l               float64
# asat:ed/l               float64
# ...

# %%
data5.corr()
# Out:
#                            num    gender   examage  heavymetals:rtut  \
# num                   1.000000  0.506334  0.001655          0.025424
# gender                0.506334  1.000000  0.102103         -0.079669
# examage               0.001655  0.102103  1.000000         -0.462390
# heavymetals:rtut      0.025424 -0.079669 -0.462390          1.000000
# heavymetals:svinec    0.015697 -0.008359  0.065820         -0.018335
# heavymetals:svinec   -0.143106  0.090527 -0.265626          0.160066
# heavymetals:svinec    0.015697 -0.008359  0.065820         -0.018335
# heavymetals:svinec   -0.143106  0.090527 -0.265626          0.160066
# heavymetals:med       0.207388 -0.131023  0.270999         -0.093049
# heavymetals:cink     -0.029288  0.047930  0.004350          0.054713
# heavymetals:kadmii   -0.060925 -0.149930 -0.252318          0.266372
# heavymetals:myshyak   0.198208 -0.022931 -0.049189          0.059914
# heavymetals:chrome    0.157187 -0.199832  0.255799         -0.106930
# ...

# %%
data5.describe()
# Out:
#                num      gender     examage  heavymetals:rtut  \
# count   778.000000  778.000000  778.000000        770.000000
# mean    622.843188    0.467866   45.938303          0.815714
# std     344.325657    0.499287   13.871493          0.794499
# min       1.000000    0.000000   16.000000          0.100000
# 25%     326.500000    0.000000   35.000000          0.400000
# 50%     670.500000    0.000000   47.000000          0.600000
# 75%     922.750000    1.000000   57.000000          0.800000
# max    1181.000000    1.000000   77.000000          5.000000
#
#        heavymetals:svinec  heavymetals:svinec  heavymetals:svinec  \
# count          778.000000          777.000000          778.000000
# mean             4.665938         1312.507593            4.665938
# std              1.912362          275.132133            1.912362
# min              0.300000          670.000000            0.300000
# 25%              3.425000         1165.300000            3.425000
# ...

# %%
data5.head()
# Out:
#    num      lastname  firstname  middlename  gender            birthdate  \
# 4  1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN     1.0  1957-01-04 00:00:00
# 5  2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN     0.0  1963-08-18 00:00:00
# 6  3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN     0.0  1958-02-07 00:00:00
# 7  4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ     1.0  1963-03-19 00:00:00
# 8  5.0       БОКАЕВА     САБИЛА         NaN     0.0  1963-06-06 00:00:00
#
#    examage  heavymetals:rtut  heavymetals:svinec  heavymetals:svinec  \
# 4     57.0               0.8                 3.2              1741.0
# 5     50.0               0.9                10.0               890.0
# 6     56.0               0.8                 5.4              1584.2
# 7     51.0               0.6                 3.0              1331.5
# 8     51.0               0.6                 3.9              1850.0
#
#         ...         albumin:%:60,3-72,8  alpha1:%:1,0-2,6  alpha2:%:7,2-11,8  \
# ...

# %%
data5.to_csv('modified.csv', encoding='utf-8-sig')

# %%
from datetime import datetime

# %%
df['column'] = df['column'].astype('|S')

# %%
data5['birthdate'] = data5['birthdate'].astype('str')

# %%
datetime.strptime(data5['birthdate'], '%y/%m/%d')
#data5['birthdate'].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-7f496e61533f> in <module>()
# ----> 1 datetime.strptime(data5['birthdate'], '%y/%m/%d')
#       2 #data5['birthdate'].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
data5['birthdate'].dtype
# Out:
# dtype('O')

# %%
data.tail()
# Out:
#         num    lastname firstname    middlename  gender  birthdate  examage  \
# 773  1175.0  ФАЙЗУЛЛАЕВ    УТЕБАЙ  ТУЖМУРАТОВИЧ     1.0 1959-05-29     55.0
# 774  1176.0     САГАТОВ    КУАНЫШ           NaN     1.0 1955-08-04     59.0
# 775  1178.0    САРБАСОВ  БАКЫТБЕК           NaN     1.0 1966-10-09     47.0
# 776  1179.0    КИЛИБАЕВ   ЕРБАХЫТ    УТЕГЕНОВИЧ     1.0 1963-08-30     51.0
# 777  1181.0    ОРАЗАШЕВ     ДУЛАТ           NaN     1.0 1988-06-15     26.0
#
#      heavymetals:rtut  heavymetals:svinec  heavymetals:svinec.1  ...  \
# 773               0.5                 4.3                1263.4  ...
# 774               0.6                 3.8                1178.4  ...
# 775               0.3                 5.0                1265.0  ...
# 776               0.4                 7.3                 912.6  ...
# 777               4.0                 5.1                3892.5  ...
#
#      albumin:%:60,3-72,8  alpha1:%:1,0-2,6  alpha2:%:7,2-11,8  \
# ...

# %%
data['birthdate'] = pd.to_datetime(data['birthdate'])

# %%
data.drop(data.columns[0], axis=1, inplace=True)

# %%
data.to_csv('modified2.csv', encoding='utf-8-sig')

# %%
data = pd.read_csv('modified2.csv')

# %%
url = 'https://github.com/botamukatova/sharing-files/blob/master/modified2.csv'
r = requests.get(url)
text = r.iter_lines()
reader = csv.reader(text)

# %%
import csv

# %%
data.head()
# Out:
#    Unnamed: 0  num      lastname  firstname  middlename  gender   birthdate  \
# 0           0  1.0     ТУЛЕГЕНОВ  ОРЫНБАСАР         NaN     1.0  1957-01-04
# 1           1  2.0  ТУЛЕМУРАТОВА       ЛИЗА         NaN     0.0  1963-08-18
# 2           2  3.0    БЕРДАЛИЕВА    АЛТЫНАЙ         NaN     0.0  1958-02-07
# 3           3  4.0       МЕГЕНОВ  БАКБЕРГЕН  АИГАЛИЕВИЧ     1.0  1963-03-19
# 4           4  5.0       БОКАЕВА     САБИЛА         NaN     0.0  1963-06-06
#
#    examage  heavymetals:rtut  heavymetals:svinec  ...  albumin:%:60,3-72,8  \
# 0     57.0               0.8                 3.2  ...                  2.6
# 1     50.0               0.9                10.0  ...                  2.2
# 2     56.0               0.8                 5.4  ...                  NaN
# 3     51.0               0.6                 3.0  ...                  NaN
# 4     51.0               0.6                 3.9  ...                  NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 50 columns):
# Unnamed: 0              778 non-null int64
# num                     778 non-null float64
# lastname                778 non-null object
# firstname               778 non-null object
# middlename              469 non-null object
# gender                  778 non-null float64
# birthdate               778 non-null object
# examage                 778 non-null float64
# heavymetals:rtut        770 non-null float64
# heavymetals:svinec      778 non-null float64
# heavymetals:svinec.1    777 non-null float64
# heavymetals:svinec.2    778 non-null float64
# heavymetals:svinec.3    777 non-null float64
# heavymetals:med         778 non-null float64
# heavymetals:cink        778 non-null float64
# heavymetals:kadmii      778 non-null float64
# heavymetals:myshyak     778 non-null float64
# heavymetals:chrome      778 non-null float64
# heavymetals:selen       777 non-null float64
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0          num      gender     examage  heavymetals:rtut  \
# count  778.000000   778.000000  778.000000  778.000000        770.000000
# mean   388.500000   622.843188    0.467866   45.938303          0.815714
# std    224.733546   344.325657    0.499287   13.871493          0.794499
# min      0.000000     1.000000    0.000000   16.000000          0.100000
# 25%    194.250000   326.500000    0.000000   35.000000          0.400000
# 50%    388.500000   670.500000    0.000000   47.000000          0.600000
# 75%    582.750000   922.750000    1.000000   57.000000          0.800000
# max    777.000000  1181.000000    1.000000   77.000000          5.000000
#
#        heavymetals:svinec  heavymetals:svinec.1  heavymetals:svinec.2  \
# count          778.000000            777.000000            778.000000
# mean             4.665938           1312.507593              4.665938
# std              1.912362            275.132133              1.912362
# ...

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'num',
#  'lastname',
#  'firstname',
#  'middlename',
#  'gender',
#  'birthdate',
#  'examage',
#  'heavymetals:rtut',
#  'heavymetals:svinec',
#  'heavymetals:svinec.1',
#  'heavymetals:svinec.2',
#  'heavymetals:svinec.3',
#  'heavymetals:med',
#  'heavymetals:cink',
#  'heavymetals:kadmii',
#  'heavymetals:myshyak',
#  'heavymetals:chrome',
#  'heavymetals:selen',
#  'heavymetals:marganec',
#  'heavymetals:zhelezo',
#  'heavymetals:nikel',
#  'heavymetals:iod',
#  'gemoglobin:g/l',
#  'erotrocity:x1012/l',
#  'leikocity:x109/l',
#  'tromboocity:x109/l',
#  'coe:mm/ch',
#  'alat:ed/l',
#  'asat:ed/l',
#  'amilaza:ed/l',
#  'belok:g/l',
#  'glukoza:mmol/l',
#  'ggt:ed/l',
#  'kreatin:mkmol/l',
#  'mochevina:mmol/l',
#  'shelf:ed/l',
#  'holest:mmol/l',
#  'triglic:mkmol/l',
#  'mochkislota:mkmol/l',
#  'albumin:%:60,3-72,8',
#  'alpha1:%:1,0-2,6',
#  'alpha2:%:7,2-11,8',
#  'beta1:%:5,6-9,1',
#  'beta2:%:2,2-5,7',
#  'gamma:%:1,8-9,18',
#  'hdl:%:38,6-69,4',
# ...

# %%
sns.pairplot(data)
# Out:
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\matplotlib\axes\_axes.py:6575: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\botagoz.mukatova\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\matplotlib\axes\_axes.py:6576: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
sns.distplot(data['gemoglobin:g/l'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-675c1e5403b8> in <module>
# ----> 1 sns.distplot(data['gemoglobin:g/l'])
#
# ~\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\AppData\Local\Continuum\anaconda3\envs\venv2\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ...
